# %%
import numpy as np
import os,sys
from xyz2vasp import *

# %%
vasp2xyz('CONTCAR')

# %%
file_name="Au9Pt4+"          #* do NOT include .xyz
eleNames = ['Au', 'Pt']
boxadd = 20
#! in INCAR the order of elements is very important!!!

xyz2vasp(file_name, eleNames, boxadd)
